# %%
import numpy as np 
import random as rd 

a = np.random.randint(0 ,100 , [100, 5])
print(a)
# Out:
# [[50 13 18 76 86]
#  [92 56 60 34  5]
#  [47 55 81 39 86]
#  [75 73 97 60 40]
#  [47 25 18 81 96]]
