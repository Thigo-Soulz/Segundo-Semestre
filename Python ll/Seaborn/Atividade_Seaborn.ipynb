# %%
import seaborn as sns
import pandas as pd
tips = pd.read_csv('CSV/flights.csv',sep=',')
sns.catplot(x= "month" ,data=tips, kind='count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 import pandas as pd
#       3 tips = pd.read_csv('CSV/flights.csv',sep=',')
# ----> 4 sns.catplot(x= "passengers",data= flights, kind="month")
#
# NameError: name 'flights' is not defined
