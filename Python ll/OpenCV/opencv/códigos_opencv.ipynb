# %%
import cv2
import numpy as np

# %%
dog = cv2.imread('dog.jpg', cv2.IMREAD_COLOR)
dog_cinza = cv2.imread('dog.jpg',cv2.IMREAD_GRAYSCALE)
dog_transp = cv2.imread('dog.jpg',cv2.IMREAD_UNCHANGED)

# %%
cv2.imshow('dog',dog)
x = cv2.waitKey(0)
print('TELA APERTADA',x)
cv2.destroyAllWindows()
# Out:
# TELA APERTADA -1

# %%
cv2.destroyAllWindows
cv2.imwrite('dog_cinza.jpg',dog_cinza)
# Out:
# True

# %%
import numpy as np
img = np.zeros((512,512,3), np.uint8)
cv2.line(img,(150,0),(150,512), (255,255,255), 5)
cv2.line(img,(350,0),(350,512), (255,255,255), 5)


cv2.line(img,(0,150),(512,150), (255,255,255), 5)
cv2.line(img,(0,350),(512,350), (255,255,255), 5)


cv2.imshow('tic-tac-toc',img)
cv2.waitKey(0) & 0xff
cv2.destroyAllWindows()

# %%
cv2.rectangle(img , (200,200), (300,300), (0,255,0), -1)
cv2.imshow('tic-tac-toc',img)
cv2.waitKey(0) & 0xff
cv2.destroyAllWindows()

# %%
cv2.circle (img, (75,75), 50, (0,0,255), -1)
cv2.imshow('tic-tac-toc',img)
cv2.waitKey(0) & 0xff
cv2.destroyAllWindows()

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

texto = "Tabuleiro maneiro"

cv2.putText(img, texto,(50,500), font,1.5, (191,0,191), 4, cv2.LINE_AA)
cv2.imshow('tic-tac-toc',img)
cv2.waitKey(0) & 0xff
cv2.destroyAllWindows()

# %%
import numpy as np
img = np.zeros((512,512,3), np.uint8)

cv2.rectangle(img, (200,200), (300,300),(0,255,0), -1)

cv2.circle(img, (75,75), 50 ,(255,0,0), -1)

cv2.ellipse(img, (450,450),(60,20),0,0,360,(123,0,100), -1)




cv2.imshow('tic-tac-toc',img)
x = str(cv2.waitKey(0))
cv2.destroyAllWindows()

img1 = np.zeros((512,512,3), np.uint8)

cv2.putText(img1, x,(220,226), font,1.5, (191,0,191), 4, cv2.LINE_AA)

cv2.imshow('tic-tac-toc',img1)
cv2.waitKey(1000) & 0xff
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 19
#      15 cv2.destroyAllWindows()
#      17 img1 = np.zeros((512,512,3), np.uint8)
# ---> 19 cv2.putText(img1, x,(220,226), font,1.5, (191,0,191), 4, cv2.LINE_AA)
#      21 cv2.imshow('tic-tac-toc',img1)
#      22 cv2.waitKey(1000) & 0xff
#
# NameError: name 'font' is not defined

# %%
import cv2
image = cv2.imread('dog.jpg')
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

cv2.imshow('Dog_HSV', image_hsv)
cv2.imshow('Original', image)

cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ## MOUSE

# %%
import cv2
cap = cv2.VideoCapture('video_car.mp4') # Armazenar o vídeo
ret, frame = cap.read() # Retorna bool, e o frame (True se houver um frame)
while(True):
    ret, frame = cap.read()
    if ret == False:
        break
    cv2.imshow('Corrida', frame)
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture('video_car.avi')
while(cap.isOpened()):
    ret, frame = cap.read()
    if(cv2.waitKey(1) == ord('q') or ret == False):
        break
    cv2.imshow('frame', frame)
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture('video_car.avi')
fourcc = cv2.VideoWriter_fourcc(*'XVID')
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        frame2 = cv2.resize(frame, (300,300))
        output.write(frame2)
        cv2.imshow('frame', frame2)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            reak
 else:
 break
cap.release()
output.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 3
#       1 import cv2
#       2 cap1 = cv2.VideoCapture('video_car.mp4') # Armazenar o vídeo
# ----> 3 cap = cv2.cvtColor(cap, cv2.COLOR_BGR2HLS)
#       4 ret, frame = cap1.read() # Retorna bool, e o frame (True se houver um frame)
#       5 while(True):
#
# error: OpenCV(4.13.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
